# %%
import libadalang as lal
from pathlib import Path
from typing import Generator, List, Set

# def get_full_statement_start_line(start: lal.AdaNode) -> int:
#     print(f'{start.kind_name}: {start.sloc_range}')
#     for node in start.parent_chain:
#         if isinstance(node, lal.AdaNodeList) or isinstance(node, lal.CompilationUnit):
#             return node.sloc_range.start.line
#     print(f'Not found: {start}')

def inrange(sloc: lal.Sloc, sloc_range: lal.SlocRange) -> bool:
    start = sloc_range.start
    end = sloc_range.end
    if start.line == end.line == sloc.line:
        return start.column <= sloc.column <= end.column
    elif start.line == sloc.line and start.column > sloc.column:
        return False
    elif end.line == sloc.line and end.column < sloc.column:
        return False
    return start.line <= sloc.line <= end.line

def custom_lookup(node: lal.AdaNode, loc: lal.Sloc) -> lal.AdaNode:
    if len(node.children) == 0: return node
    for child in node.children:
        if child is None: continue
        if inrange(loc, child.sloc_range):
            return custom_lookup(child, loc)
    return node

def is_unpredictable_node(node: lal.AdaNode, loc: lal.Sloc) -> bool:
    if isinstance(node, lal.SubpBody):
        print("Location:", loc)
        print("S:", node.f_subp_spec.sloc_range.end)
        print("E:", node.f_decls.sloc_range.start)
        if loc > node.f_subp_spec.sloc_range.end and loc < node.f_decls.sloc_range.start:
            return True
    for parent in node.parent_chain:
        if isinstance(parent, lal.EndName):
            return True
        if isinstance(parent, lal.CompilationUnit):
            return False
    return False

def get_unpredictable_line_numbers(root: lal.AdaNode, lines: List[str]) -> Set[int]:
    result = set()
    for i, line in enumerate(lines):
        loc = lal.Sloc(i+1, len(line.rstrip('\r\n')))
        node = custom_lookup(root, loc)
        print('Location:', loc)
        print('Lookup:', node)
        print('Parents: ', node.parent_chain)
        if is_unpredictable_node(node, loc):
            result.add(i + 1)
    return result

def create_blocks(file_path: Path) -> Generator[List[str], None, None]:
    with open(str(file_path), "r", encoding="utf-8") as f:
        lines = f.readlines()

    # Remove lines which are just whitespace
    lines = list(filter(lambda line: len(line.strip()) > 0, lines))

    context = lal.AnalysisContext()
    unit = context.get_from_buffer(file_path.name, ''.join(lines))
    root = unit.root
    root.dump()
    unpredictable = get_unpredictable_line_numbers(root, lines)
    print('Unpredictable:', unpredictable)
    for i in range(len(lines)):
        loc = lal.Sloc(i+1, len(lines[i].rstrip('\r\n')))
        res = custom_lookup(root, loc)
        if len(res.children) > 0:
            for child in res.children:
                if child is None: continue
                if test_child := child.lookup(loc) != None:
                    print('Found:', test_child)
        if res is not None:
            print('Found:', res.kind_name, res.sloc_range)
            # start = get_full_statement_start_line(res)
            print('---')
            # print(''.join(lines[start-1:i+1]))
        # sloc = res.sloc_range
        # print(sloc.start, sloc.end)
        # yield [res.text, sloc.start, sloc.end]
    yield None


file_path = Path("/workspaces/ai-indent/data/interim/complete_files/ada/21425_c.ada")

# %%
for block in create_blocks(file_path):
    pass
# Out:
# CompilationUnitList 21425_c.ada:1:1-21:7
# |item_0:
# |  CompilationUnit 21425_c.ada:1:1-3:7
# |  |prelude:
# |  |  AdaNodeList 21425_c.ada:1:1-1:1
# |  |body:
# |  |  LibraryItem 21425_c.ada:1:1-3:7
# |  |  |has_private:
# |  |  |  PrivateAbsent 21425_c.ada:1:1-1:1
# |  |  |item:
# |  |  |  PackageDecl ["A"] 21425_c.ada:1:1-3:7
# |  |  |  |package_name:
# |  |  |  |  DefiningName 21425_c.ada:1:9-1:10
# |  |  |  |  |name:
# |  |  |  |  |  Id "A" 21425_c.ada:1:9-1:10: A
# |  |  |  |aspects: None
# |  |  |  |public_part:
# |  |  |  |  PublicPart 21425_c.ada:1:13-3:1
# |  |  |  |  |decls:
# |  |  |  |  |  AdaNodeList 21425_c.ada:1:14-2:39
# |  |  |  |  |  |item_0:
# |  |  |  |  |  |  PragmaNode 21425_c.ada:1:14-1:37
# |  |  |  |  |  |  |id:
# |  |  |  |  |  |  |  Id "SPARK_Mode" 21425_c.ada:1:21-1:31: SPARK_Mode
# |  |  |  |  |  |  |args:
# |  |  |  |  |  |  |  BaseAssocList 21425_c.ada:1:33-1:35
# |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  PragmaArgumentAssoc 21425_c.ada:1:33-1:35
# |  |  |  |  |  |  |  |  |name: None
# |  |  |  |  |  |  |  |  |expr:
# |  |  |  |  |  |  |  |  |  Id "On" 21425_c.ada:1:33-1:35: On
# |  |  |  |  |  |item_1:
# |  |  |  |  |  |  SubpDecl ["Foo"] 21425_c.ada:2:4-2:39
# |  |  |  |  |  |  |overriding:
# |  |  |  |  |  |  |  OverridingUnspecified 21425_c.ada:1:37-1:37
# |  |  |  |  |  |  |subp_spec:
# |  |  |  |  |  |  |  SubpSpec 21425_c.ada:2:4-2:38
# |  |  |  |  |  |  |  |subp_kind:
# |  |  |  |  |  |  |  |  SubpKindProcedure 21425_c.ada:2:4-2:13
# |  |  |  |  |  |  |  |subp_name:
# |  |  |  |  |  |  |  |  DefiningName 21425_c.ada:2:14-2:17
# |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  Id "Foo" 21425_c.ada:2:14-2:17: Foo
# |  |  |  |  |  |  |  |subp_params:
# |  |  |  |  |  |  |  |  Params 21425_c.ada:2:18-2:38
# |  |  |  |  |  |  |  |  |params:
# |  |  |  |  |  |  |  |  |  ParamSpecList 21425_c.ada:2:19-2:37
# |  |  |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  |  |  ParamSpec ["X"] 21425_c.ada:2:19-2:37
# |  |  |  |  |  |  |  |  |  |  |ids:
# |  |  |  |  |  |  |  |  |  |  |  DefiningNameList 21425_c.ada:2:19-2:20
# |  |  |  |  |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  |  |  |  |  DefiningName 21425_c.ada:2:19-2:20
# |  |  |  |  |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  |  |  |  |  Id "X" 21425_c.ada:2:19-2:20: X
# |  |  |  |  |  |  |  |  |  |  |has_aliased:
# |  |  |  |  |  |  |  |  |  |  |  AliasedAbsent 21425_c.ada:2:22-2:22
# |  |  |  |  |  |  |  |  |  |  |mode:
# |  |  |  |  |  |  |  |  |  |  |  ModeInOut 21425_c.ada:2:23-2:29
# |  |  |  |  |  |  |  |  |  |  |type_expr:
# |  |  |  |  |  |  |  |  |  |  |  SubtypeIndication 21425_c.ada:2:30-2:37
# |  |  |  |  |  |  |  |  |  |  |  |has_not_null:
# |  |  |  |  |  |  |  |  |  |  |  |  NotNullAbsent 21425_c.ada:2:29-2:29
# |  |  |  |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  |  |  |  Id "Integer" 21425_c.ada:2:30-2:37: Integer
# |  |  |  |  |  |  |  |  |  |  |  |constraint: None
# |  |  |  |  |  |  |  |  |  |  |default_expr: None
# |  |  |  |  |  |  |  |  |  |  |aspects: None
# |  |  |  |  |  |  |  |subp_returns: None
# |  |  |  |  |  |  |aspects: None
# |  |  |  |private_part: None
# |  |  |  |end_name:
# |  |  |  |  EndName 21425_c.ada:3:5-3:6
# |  |  |  |  |name:
# |  |  |  |  |  Id "A" 21425_c.ada:3:5-3:6: A
# |  |pragmas:
# |  |  PragmaNodeList 21425_c.ada:3:7-3:7
# |item_1:
# |  CompilationUnit 21425_c.ada:4:1-12:7
# |  |prelude:
# |  |  AdaNodeList 21425_c.ada:4:1-4:8
# |  |  |item_0:
# |  |  |  WithClause 21425_c.ada:4:1-4:8
# |  |  |  |has_limited:
# |  |  |  |  LimitedAbsent 21425_c.ada:3:7-3:7
# |  |  |  |has_private:
# |  |  |  |  PrivateAbsent 21425_c.ada:3:7-3:7
# |  |  |  |packages:
# |  |  |  |  NameList 21425_c.ada:4:6-4:7
# |  |  |  |  |item_0:
# |  |  |  |  |  Id "B" 21425_c.ada:4:6-4:7: B
# |  |body:
# |  |  LibraryItem 21425_c.ada:5:1-12:7
# |  |  |has_private:
# |  |  |  PrivateAbsent 21425_c.ada:4:8-4:8
# |  |  |item:
# |  |  |  PackageBody ["A"] 21425_c.ada:5:1-12:7
# |  |  |  |package_name:
# |  |  |  |  DefiningName 21425_c.ada:5:14-5:15
# |  |  |  |  |name:
# |  |  |  |  |  Id "A" 21425_c.ada:5:14-5:15: A
# |  |  |  |aspects: None
# |  |  |  |decls:
# |  |  |  |  DeclarativePart 21425_c.ada:5:18-12:1
# |  |  |  |  |decls:
# |  |  |  |  |  AdaNodeList 21425_c.ada:5:19-11:12
# |  |  |  |  |  |item_0:
# |  |  |  |  |  |  PragmaNode 21425_c.ada:5:19-5:42
# |  |  |  |  |  |  |id:
# |  |  |  |  |  |  |  Id "SPARK_Mode" 21425_c.ada:5:26-5:36: SPARK_Mode
# |  |  |  |  |  |  |args:
# |  |  |  |  |  |  |  BaseAssocList 21425_c.ada:5:38-5:40
# |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  PragmaArgumentAssoc 21425_c.ada:5:38-5:40
# |  |  |  |  |  |  |  |  |name: None
# |  |  |  |  |  |  |  |  |expr:
# |  |  |  |  |  |  |  |  |  Id "On" 21425_c.ada:5:38-5:40: On
# |  |  |  |  |  |item_1:
# |  |  |  |  |  |  SubpBody ["Foo"] 21425_c.ada:6:4-11:12
# |  |  |  |  |  |  |overriding:
# |  |  |  |  |  |  |  OverridingUnspecified 21425_c.ada:5:42-5:42
# |  |  |  |  |  |  |subp_spec:
# |  |  |  |  |  |  |  SubpSpec 21425_c.ada:6:4-6:38
# |  |  |  |  |  |  |  |subp_kind:
# |  |  |  |  |  |  |  |  SubpKindProcedure 21425_c.ada:6:4-6:13
# |  |  |  |  |  |  |  |subp_name:
# |  |  |  |  |  |  |  |  DefiningName 21425_c.ada:6:14-6:17
# |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  Id "Foo" 21425_c.ada:6:14-6:17: Foo
# |  |  |  |  |  |  |  |subp_params:
# |  |  |  |  |  |  |  |  Params 21425_c.ada:6:18-6:38
# |  |  |  |  |  |  |  |  |params:
# |  |  |  |  |  |  |  |  |  ParamSpecList 21425_c.ada:6:19-6:37
# |  |  |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  |  |  ParamSpec ["X"] 21425_c.ada:6:19-6:37
# |  |  |  |  |  |  |  |  |  |  |ids:
# |  |  |  |  |  |  |  |  |  |  |  DefiningNameList 21425_c.ada:6:19-6:20
# |  |  |  |  |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  |  |  |  |  DefiningName 21425_c.ada:6:19-6:20
# |  |  |  |  |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  |  |  |  |  Id "X" 21425_c.ada:6:19-6:20: X
# |  |  |  |  |  |  |  |  |  |  |has_aliased:
# |  |  |  |  |  |  |  |  |  |  |  AliasedAbsent 21425_c.ada:6:22-6:22
# |  |  |  |  |  |  |  |  |  |  |mode:
# |  |  |  |  |  |  |  |  |  |  |  ModeInOut 21425_c.ada:6:23-6:29
# |  |  |  |  |  |  |  |  |  |  |type_expr:
# |  |  |  |  |  |  |  |  |  |  |  SubtypeIndication 21425_c.ada:6:30-6:37
# |  |  |  |  |  |  |  |  |  |  |  |has_not_null:
# |  |  |  |  |  |  |  |  |  |  |  |  NotNullAbsent 21425_c.ada:6:29-6:29
# |  |  |  |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  |  |  |  Id "Integer" 21425_c.ada:6:30-6:37: Integer
# |  |  |  |  |  |  |  |  |  |  |  |constraint: None
# |  |  |  |  |  |  |  |  |  |  |default_expr: None
# |  |  |  |  |  |  |  |  |  |  |aspects: None
# |  |  |  |  |  |  |  |subp_returns: None
# |  |  |  |  |  |  |aspects: None
# |  |  |  |  |  |  |decls:
# |  |  |  |  |  |  |  DeclarativePart 21425_c.ada:6:41-8:4
# |  |  |  |  |  |  |  |decls:
# |  |  |  |  |  |  |  |  AdaNodeList 21425_c.ada:7:7-7:19
# |  |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  |  ObjectDecl ["Y"] 21425_c.ada:7:7-7:19
# |  |  |  |  |  |  |  |  |  |ids:
# |  |  |  |  |  |  |  |  |  |  DefiningNameList 21425_c.ada:7:7-7:8
# |  |  |  |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  |  |  |  DefiningName 21425_c.ada:7:7-7:8
# |  |  |  |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  |  |  |  Id "Y" 21425_c.ada:7:7-7:8: Y
# |  |  |  |  |  |  |  |  |  |has_aliased:
# |  |  |  |  |  |  |  |  |  |  AliasedAbsent 21425_c.ada:7:10-7:10
# |  |  |  |  |  |  |  |  |  |has_constant:
# |  |  |  |  |  |  |  |  |  |  ConstantAbsent 21425_c.ada:7:10-7:10
# |  |  |  |  |  |  |  |  |  |mode:
# |  |  |  |  |  |  |  |  |  |  ModeDefault 21425_c.ada:7:10-7:10
# |  |  |  |  |  |  |  |  |  |type_expr:
# |  |  |  |  |  |  |  |  |  |  SubtypeIndication 21425_c.ada:7:11-7:18
# |  |  |  |  |  |  |  |  |  |  |has_not_null:
# |  |  |  |  |  |  |  |  |  |  |  NotNullAbsent 21425_c.ada:7:10-7:10
# |  |  |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  |  |  Id "Integer" 21425_c.ada:7:11-7:18: Integer
# |  |  |  |  |  |  |  |  |  |  |constraint: None
# |  |  |  |  |  |  |  |  |  |default_expr: None
# |  |  |  |  |  |  |  |  |  |renaming_clause: None
# |  |  |  |  |  |  |  |  |  |aspects: None
# |  |  |  |  |  |  |stmts:
# |  |  |  |  |  |  |  HandledStmts 21425_c.ada:8:9-11:4
# |  |  |  |  |  |  |  |stmts:
# |  |  |  |  |  |  |  |  StmtList 21425_c.ada:9:7-10:18
# |  |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  |  CallStmt 21425_c.ada:9:7-9:17
# |  |  |  |  |  |  |  |  |  |call:
# |  |  |  |  |  |  |  |  |  |  CallExpr 21425_c.ada:9:7-9:16
# |  |  |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  |  |  DottedName 21425_c.ada:9:7-9:12
# |  |  |  |  |  |  |  |  |  |  |  |prefix:
# |  |  |  |  |  |  |  |  |  |  |  |  Id "B" 21425_c.ada:9:7-9:8: B
# |  |  |  |  |  |  |  |  |  |  |  |suffix:
# |  |  |  |  |  |  |  |  |  |  |  |  Id "Bar" 21425_c.ada:9:9-9:12: Bar
# |  |  |  |  |  |  |  |  |  |  |suffix:
# |  |  |  |  |  |  |  |  |  |  |  AssocList 21425_c.ada:9:14-9:15
# |  |  |  |  |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  |  |  |  |  ParamAssoc 21425_c.ada:9:14-9:15
# |  |  |  |  |  |  |  |  |  |  |  |  |designator: None
# |  |  |  |  |  |  |  |  |  |  |  |  |r_expr:
# |  |  |  |  |  |  |  |  |  |  |  |  |  Id "X" 21425_c.ada:9:14-9:15: X
# |  |  |  |  |  |  |  |  |item_1:
# |  |  |  |  |  |  |  |  |  AssignStmt 21425_c.ada:10:7-10:18
# |  |  |  |  |  |  |  |  |  |dest:
# |  |  |  |  |  |  |  |  |  |  Id "X" 21425_c.ada:10:7-10:8: X
# |  |  |  |  |  |  |  |  |  |expr:
# |  |  |  |  |  |  |  |  |  |  BinOp 21425_c.ada:10:12-10:17
# |  |  |  |  |  |  |  |  |  |  |left:
# |  |  |  |  |  |  |  |  |  |  |  Id "X" 21425_c.ada:10:12-10:13: X
# |  |  |  |  |  |  |  |  |  |  |op:
# |  |  |  |  |  |  |  |  |  |  |  OpPlus "+" 21425_c.ada:10:14-10:15
# |  |  |  |  |  |  |  |  |  |  |right:
# |  |  |  |  |  |  |  |  |  |  |  Int 21425_c.ada:10:16-10:17: 1
# |  |  |  |  |  |  |  |exceptions:
# |  |  |  |  |  |  |  |  AdaNodeList 21425_c.ada:10:17-10:17
# |  |  |  |  |  |  |end_name:
# |  |  |  |  |  |  |  EndName 21425_c.ada:11:8-11:11
# |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  Id "Foo" 21425_c.ada:11:8-11:11: Foo
# |  |  |  |stmts: None
# |  |  |  |end_name:
# |  |  |  |  EndName 21425_c.ada:12:5-12:6
# |  |  |  |  |name:
# |  |  |  |  |  Id "A" 21425_c.ada:12:5-12:6: A
# |  |pragmas:
# |  |  PragmaNodeList 21425_c.ada:12:7-12:7
# |item_2:
# |  CompilationUnit 21425_c.ada:13:1-15:7
# |  |prelude:
# |  |  AdaNodeList 21425_c.ada:12:7-12:7
# |  |body:
# |  |  LibraryItem 21425_c.ada:13:1-15:7
# |  |  |has_private:
# |  |  |  PrivateAbsent 21425_c.ada:12:7-12:7
# |  |  |item:
# |  |  |  PackageDecl ["B"] 21425_c.ada:13:1-15:7
# |  |  |  |package_name:
# |  |  |  |  DefiningName 21425_c.ada:13:9-13:10
# |  |  |  |  |name:
# |  |  |  |  |  Id "B" 21425_c.ada:13:9-13:10: B
# |  |  |  |aspects: None
# |  |  |  |public_part:
# |  |  |  |  PublicPart 21425_c.ada:13:13-15:1
# |  |  |  |  |decls:
# |  |  |  |  |  AdaNodeList 21425_c.ada:13:14-14:39
# |  |  |  |  |  |item_0:
# |  |  |  |  |  |  PragmaNode 21425_c.ada:13:14-13:37
# |  |  |  |  |  |  |id:
# |  |  |  |  |  |  |  Id "SPARK_Mode" 21425_c.ada:13:21-13:31: SPARK_Mode
# |  |  |  |  |  |  |args:
# |  |  |  |  |  |  |  BaseAssocList 21425_c.ada:13:33-13:35
# |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  PragmaArgumentAssoc 21425_c.ada:13:33-13:35
# |  |  |  |  |  |  |  |  |name: None
# |  |  |  |  |  |  |  |  |expr:
# |  |  |  |  |  |  |  |  |  Id "On" 21425_c.ada:13:33-13:35: On
# |  |  |  |  |  |item_1:
# |  |  |  |  |  |  SubpDecl ["Bar"] 21425_c.ada:14:4-14:39
# |  |  |  |  |  |  |overriding:
# |  |  |  |  |  |  |  OverridingUnspecified 21425_c.ada:13:37-13:37
# |  |  |  |  |  |  |subp_spec:
# |  |  |  |  |  |  |  SubpSpec 21425_c.ada:14:4-14:38
# |  |  |  |  |  |  |  |subp_kind:
# |  |  |  |  |  |  |  |  SubpKindProcedure 21425_c.ada:14:4-14:13
# |  |  |  |  |  |  |  |subp_name:
# |  |  |  |  |  |  |  |  DefiningName 21425_c.ada:14:14-14:17
# |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  Id "Bar" 21425_c.ada:14:14-14:17: Bar
# |  |  |  |  |  |  |  |subp_params:
# |  |  |  |  |  |  |  |  Params 21425_c.ada:14:18-14:38
# |  |  |  |  |  |  |  |  |params:
# |  |  |  |  |  |  |  |  |  ParamSpecList 21425_c.ada:14:19-14:37
# |  |  |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  |  |  ParamSpec ["X"] 21425_c.ada:14:19-14:37
# |  |  |  |  |  |  |  |  |  |  |ids:
# |  |  |  |  |  |  |  |  |  |  |  DefiningNameList 21425_c.ada:14:19-14:20
# |  |  |  |  |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  |  |  |  |  DefiningName 21425_c.ada:14:19-14:20
# |  |  |  |  |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  |  |  |  |  Id "X" 21425_c.ada:14:19-14:20: X
# |  |  |  |  |  |  |  |  |  |  |has_aliased:
# |  |  |  |  |  |  |  |  |  |  |  AliasedAbsent 21425_c.ada:14:22-14:22
# |  |  |  |  |  |  |  |  |  |  |mode:
# |  |  |  |  |  |  |  |  |  |  |  ModeInOut 21425_c.ada:14:23-14:29
# |  |  |  |  |  |  |  |  |  |  |type_expr:
# |  |  |  |  |  |  |  |  |  |  |  SubtypeIndication 21425_c.ada:14:30-14:37
# |  |  |  |  |  |  |  |  |  |  |  |has_not_null:
# |  |  |  |  |  |  |  |  |  |  |  |  NotNullAbsent 21425_c.ada:14:29-14:29
# |  |  |  |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  |  |  |  Id "Integer" 21425_c.ada:14:30-14:37: Integer
# |  |  |  |  |  |  |  |  |  |  |  |constraint: None
# |  |  |  |  |  |  |  |  |  |  |default_expr: None
# |  |  |  |  |  |  |  |  |  |  |aspects: None
# |  |  |  |  |  |  |  |subp_returns: None
# |  |  |  |  |  |  |aspects: None
# |  |  |  |private_part: None
# |  |  |  |end_name:
# |  |  |  |  EndName 21425_c.ada:15:5-15:6
# |  |  |  |  |name:
# |  |  |  |  |  Id "B" 21425_c.ada:15:5-15:6: B
# |  |pragmas:
# |  |  PragmaNodeList 21425_c.ada:15:7-15:7
# |item_3:
# |  CompilationUnit 21425_c.ada:16:1-21:7
# |  |prelude:
# |  |  AdaNodeList 21425_c.ada:15:7-15:7
# |  |body:
# |  |  LibraryItem 21425_c.ada:16:1-21:7
# |  |  |has_private:
# |  |  |  PrivateAbsent 21425_c.ada:15:7-15:7
# |  |  |item:
# |  |  |  PackageBody ["B"] 21425_c.ada:16:1-21:7
# |  |  |  |package_name:
# |  |  |  |  DefiningName 21425_c.ada:16:14-16:15
# |  |  |  |  |name:
# |  |  |  |  |  Id "B" 21425_c.ada:16:14-16:15: B
# |  |  |  |aspects: None
# |  |  |  |decls:
# |  |  |  |  DeclarativePart 21425_c.ada:16:18-21:1
# |  |  |  |  |decls:
# |  |  |  |  |  AdaNodeList 21425_c.ada:16:19-20:12
# |  |  |  |  |  |item_0:
# |  |  |  |  |  |  PragmaNode 21425_c.ada:16:19-16:42
# |  |  |  |  |  |  |id:
# |  |  |  |  |  |  |  Id "SPARK_Mode" 21425_c.ada:16:26-16:36: SPARK_Mode
# |  |  |  |  |  |  |args:
# |  |  |  |  |  |  |  BaseAssocList 21425_c.ada:16:38-16:40
# |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  PragmaArgumentAssoc 21425_c.ada:16:38-16:40
# |  |  |  |  |  |  |  |  |name: None
# |  |  |  |  |  |  |  |  |expr:
# |  |  |  |  |  |  |  |  |  Id "On" 21425_c.ada:16:38-16:40: On
# |  |  |  |  |  |item_1:
# |  |  |  |  |  |  SubpBody ["Bar"] 21425_c.ada:17:4-20:12
# |  |  |  |  |  |  |overriding:
# |  |  |  |  |  |  |  OverridingUnspecified 21425_c.ada:16:42-16:42
# |  |  |  |  |  |  |subp_spec:
# |  |  |  |  |  |  |  SubpSpec 21425_c.ada:17:4-17:38
# |  |  |  |  |  |  |  |subp_kind:
# |  |  |  |  |  |  |  |  SubpKindProcedure 21425_c.ada:17:4-17:13
# |  |  |  |  |  |  |  |subp_name:
# |  |  |  |  |  |  |  |  DefiningName 21425_c.ada:17:14-17:17
# |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  Id "Bar" 21425_c.ada:17:14-17:17: Bar
# |  |  |  |  |  |  |  |subp_params:
# |  |  |  |  |  |  |  |  Params 21425_c.ada:17:18-17:38
# |  |  |  |  |  |  |  |  |params:
# |  |  |  |  |  |  |  |  |  ParamSpecList 21425_c.ada:17:19-17:37
# |  |  |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  |  |  ParamSpec ["X"] 21425_c.ada:17:19-17:37
# |  |  |  |  |  |  |  |  |  |  |ids:
# |  |  |  |  |  |  |  |  |  |  |  DefiningNameList 21425_c.ada:17:19-17:20
# |  |  |  |  |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  |  |  |  |  DefiningName 21425_c.ada:17:19-17:20
# |  |  |  |  |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  |  |  |  |  Id "X" 21425_c.ada:17:19-17:20: X
# |  |  |  |  |  |  |  |  |  |  |has_aliased:
# |  |  |  |  |  |  |  |  |  |  |  AliasedAbsent 21425_c.ada:17:22-17:22
# |  |  |  |  |  |  |  |  |  |  |mode:
# |  |  |  |  |  |  |  |  |  |  |  ModeInOut 21425_c.ada:17:23-17:29
# |  |  |  |  |  |  |  |  |  |  |type_expr:
# |  |  |  |  |  |  |  |  |  |  |  SubtypeIndication 21425_c.ada:17:30-17:37
# |  |  |  |  |  |  |  |  |  |  |  |has_not_null:
# |  |  |  |  |  |  |  |  |  |  |  |  NotNullAbsent 21425_c.ada:17:29-17:29
# |  |  |  |  |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  |  |  |  |  Id "Integer" 21425_c.ada:17:30-17:37: Integer
# |  |  |  |  |  |  |  |  |  |  |  |constraint: None
# |  |  |  |  |  |  |  |  |  |  |default_expr: None
# |  |  |  |  |  |  |  |  |  |  |aspects: None
# |  |  |  |  |  |  |  |subp_returns: None
# |  |  |  |  |  |  |aspects: None
# |  |  |  |  |  |  |decls:
# |  |  |  |  |  |  |  DeclarativePart 21425_c.ada:17:41-18:4
# |  |  |  |  |  |  |  |decls:
# |  |  |  |  |  |  |  |  AdaNodeList 21425_c.ada:17:41-17:41
# |  |  |  |  |  |  |stmts:
# |  |  |  |  |  |  |  HandledStmts 21425_c.ada:18:9-20:4
# |  |  |  |  |  |  |  |stmts:
# |  |  |  |  |  |  |  |  StmtList 21425_c.ada:19:7-19:18
# |  |  |  |  |  |  |  |  |item_0:
# |  |  |  |  |  |  |  |  |  AssignStmt 21425_c.ada:19:7-19:18
# |  |  |  |  |  |  |  |  |  |dest:
# |  |  |  |  |  |  |  |  |  |  Id "X" 21425_c.ada:19:7-19:8: X
# |  |  |  |  |  |  |  |  |  |expr:
# |  |  |  |  |  |  |  |  |  |  BinOp 21425_c.ada:19:12-19:17
# |  |  |  |  |  |  |  |  |  |  |left:
# |  |  |  |  |  |  |  |  |  |  |  Id "X" 21425_c.ada:19:12-19:13: X
# |  |  |  |  |  |  |  |  |  |  |op:
# |  |  |  |  |  |  |  |  |  |  |  OpPlus "+" 21425_c.ada:19:14-19:15
# |  |  |  |  |  |  |  |  |  |  |right:
# |  |  |  |  |  |  |  |  |  |  |  Int 21425_c.ada:19:16-19:17: 1
# |  |  |  |  |  |  |  |exceptions:
# |  |  |  |  |  |  |  |  AdaNodeList 21425_c.ada:19:17-19:17
# |  |  |  |  |  |  |end_name:
# |  |  |  |  |  |  |  EndName 21425_c.ada:20:8-20:11
# |  |  |  |  |  |  |  |name:
# |  |  |  |  |  |  |  |  Id "Bar" 21425_c.ada:20:8-20:11: Bar
# |  |  |  |stmts: None
# |  |  |  |end_name:
# |  |  |  |  EndName 21425_c.ada:21:5-21:6
# |  |  |  |  |name:
# |  |  |  |  |  Id "B" 21425_c.ada:21:5-21:6: B
# |  |pragmas:
# |  |  PragmaNodeList 21425_c.ada:21:7-21:7
# Location: 1:36
# Lookup: <PragmaNode 21425_c.ada:1:14-1:37>
# Parents:  [<PragmaNode 21425_c.ada:1:14-1:37>, <AdaNodeList 21425_c.ada:1:14-2:39>, <PublicPart 21425_c.ada:1:13-3:1>, <PackageDecl ["A"] 21425_c.ada:1:1-3:7>, <LibraryItem 21425_c.ada:1:1-3:7>, <CompilationUnit 21425_c.ada:1:1-3:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 2:38
# Lookup: <Params 21425_c.ada:2:18-2:38>
# Parents:  [<Params 21425_c.ada:2:18-2:38>, <SubpSpec 21425_c.ada:2:4-2:38>, <SubpDecl ["Foo"] 21425_c.ada:2:4-2:39>, <AdaNodeList 21425_c.ada:1:14-2:39>, <PublicPart 21425_c.ada:1:13-3:1>, <PackageDecl ["A"] 21425_c.ada:1:1-3:7>, <LibraryItem 21425_c.ada:1:1-3:7>, <CompilationUnit 21425_c.ada:1:1-3:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 3:6
# Lookup: <Id "A" 21425_c.ada:3:5-3:6>
# Parents:  [<Id "A" 21425_c.ada:3:5-3:6>, <EndName 21425_c.ada:3:5-3:6>, <PackageDecl ["A"] 21425_c.ada:1:1-3:7>, <LibraryItem 21425_c.ada:1:1-3:7>, <CompilationUnit 21425_c.ada:1:1-3:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 4:7
# Lookup: <Id "B" 21425_c.ada:4:6-4:7>
# Parents:  [<Id "B" 21425_c.ada:4:6-4:7>, <NameList 21425_c.ada:4:6-4:7>, <WithClause 21425_c.ada:4:1-4:8>, <AdaNodeList 21425_c.ada:4:1-4:8>, <CompilationUnit 21425_c.ada:4:1-12:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 5:41
# Lookup: <PragmaNode 21425_c.ada:5:19-5:42>
# Parents:  [<PragmaNode 21425_c.ada:5:19-5:42>, <AdaNodeList 21425_c.ada:5:19-11:12>, <DeclarativePart 21425_c.ada:5:18-12:1>, <PackageBody ["A"] 21425_c.ada:5:1-12:7>, <LibraryItem 21425_c.ada:5:1-12:7>, <CompilationUnit 21425_c.ada:4:1-12:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 6:40
# Lookup: <SubpBody ["Foo"] 21425_c.ada:6:4-11:12>
# Parents:  [<SubpBody ["Foo"] 21425_c.ada:6:4-11:12>, <AdaNodeList 21425_c.ada:5:19-11:12>, <DeclarativePart 21425_c.ada:5:18-12:1>, <PackageBody ["A"] 21425_c.ada:5:1-12:7>, <LibraryItem 21425_c.ada:5:1-12:7>, <CompilationUnit 21425_c.ada:4:1-12:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 6:40
# S: 6:38
# E: 6:41
# Location: 7:18
# Lookup: <Id "Integer" 21425_c.ada:7:11-7:18>
# Parents:  [<Id "Integer" 21425_c.ada:7:11-7:18>, <SubtypeIndication 21425_c.ada:7:11-7:18>, <ObjectDecl ["Y"] 21425_c.ada:7:7-7:19>, <AdaNodeList 21425_c.ada:7:7-7:19>, <DeclarativePart 21425_c.ada:6:41-8:4>, <SubpBody ["Foo"] 21425_c.ada:6:4-11:12>, <AdaNodeList 21425_c.ada:5:19-11:12>, <DeclarativePart 21425_c.ada:5:18-12:1>, <PackageBody ["A"] 21425_c.ada:5:1-12:7>, <LibraryItem 21425_c.ada:5:1-12:7>, <CompilationUnit 21425_c.ada:4:1-12:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 8:8
# Lookup: <SubpBody ["Foo"] 21425_c.ada:6:4-11:12>
# Parents:  [<SubpBody ["Foo"] 21425_c.ada:6:4-11:12>, <AdaNodeList 21425_c.ada:5:19-11:12>, <DeclarativePart 21425_c.ada:5:18-12:1>, <PackageBody ["A"] 21425_c.ada:5:1-12:7>, <LibraryItem 21425_c.ada:5:1-12:7>, <CompilationUnit 21425_c.ada:4:1-12:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 8:8
# S: 6:38
# E: 6:41
# Location: 9:16
# Lookup: <CallExpr 21425_c.ada:9:7-9:16>
# Parents:  [<CallExpr 21425_c.ada:9:7-9:16>, <CallStmt 21425_c.ada:9:7-9:17>, <StmtList 21425_c.ada:9:7-10:18>, <HandledStmts 21425_c.ada:8:9-11:4>, <SubpBody ["Foo"] 21425_c.ada:6:4-11:12>, <AdaNodeList 21425_c.ada:5:19-11:12>, <DeclarativePart 21425_c.ada:5:18-12:1>, <PackageBody ["A"] 21425_c.ada:5:1-12:7>, <LibraryItem 21425_c.ada:5:1-12:7>, <CompilationUnit 21425_c.ada:4:1-12:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 10:17
# Lookup: <Int 21425_c.ada:10:16-10:17>
# Parents:  [<Int 21425_c.ada:10:16-10:17>, <BinOp 21425_c.ada:10:12-10:17>, <AssignStmt 21425_c.ada:10:7-10:18>, <StmtList 21425_c.ada:9:7-10:18>, <HandledStmts 21425_c.ada:8:9-11:4>, <SubpBody ["Foo"] 21425_c.ada:6:4-11:12>, <AdaNodeList 21425_c.ada:5:19-11:12>, <DeclarativePart 21425_c.ada:5:18-12:1>, <PackageBody ["A"] 21425_c.ada:5:1-12:7>, <LibraryItem 21425_c.ada:5:1-12:7>, <CompilationUnit 21425_c.ada:4:1-12:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 11:11
# Lookup: <Id "Foo" 21425_c.ada:11:8-11:11>
# Parents:  [<Id "Foo" 21425_c.ada:11:8-11:11>, <EndName 21425_c.ada:11:8-11:11>, <SubpBody ["Foo"] 21425_c.ada:6:4-11:12>, <AdaNodeList 21425_c.ada:5:19-11:12>, <DeclarativePart 21425_c.ada:5:18-12:1>, <PackageBody ["A"] 21425_c.ada:5:1-12:7>, <LibraryItem 21425_c.ada:5:1-12:7>, <CompilationUnit 21425_c.ada:4:1-12:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 12:6
# Lookup: <Id "A" 21425_c.ada:12:5-12:6>
# Parents:  [<Id "A" 21425_c.ada:12:5-12:6>, <EndName 21425_c.ada:12:5-12:6>, <PackageBody ["A"] 21425_c.ada:5:1-12:7>, <LibraryItem 21425_c.ada:5:1-12:7>, <CompilationUnit 21425_c.ada:4:1-12:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 13:36
# Lookup: <PragmaNode 21425_c.ada:13:14-13:37>
# Parents:  [<PragmaNode 21425_c.ada:13:14-13:37>, <AdaNodeList 21425_c.ada:13:14-14:39>, <PublicPart 21425_c.ada:13:13-15:1>, <PackageDecl ["B"] 21425_c.ada:13:1-15:7>, <LibraryItem 21425_c.ada:13:1-15:7>, <CompilationUnit 21425_c.ada:13:1-15:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 14:38
# Lookup: <Params 21425_c.ada:14:18-14:38>
# Parents:  [<Params 21425_c.ada:14:18-14:38>, <SubpSpec 21425_c.ada:14:4-14:38>, <SubpDecl ["Bar"] 21425_c.ada:14:4-14:39>, <AdaNodeList 21425_c.ada:13:14-14:39>, <PublicPart 21425_c.ada:13:13-15:1>, <PackageDecl ["B"] 21425_c.ada:13:1-15:7>, <LibraryItem 21425_c.ada:13:1-15:7>, <CompilationUnit 21425_c.ada:13:1-15:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 15:6
# Lookup: <Id "B" 21425_c.ada:15:5-15:6>
# Parents:  [<Id "B" 21425_c.ada:15:5-15:6>, <EndName 21425_c.ada:15:5-15:6>, <PackageDecl ["B"] 21425_c.ada:13:1-15:7>, <LibraryItem 21425_c.ada:13:1-15:7>, <CompilationUnit 21425_c.ada:13:1-15:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 16:41
# Lookup: <PragmaNode 21425_c.ada:16:19-16:42>
# Parents:  [<PragmaNode 21425_c.ada:16:19-16:42>, <AdaNodeList 21425_c.ada:16:19-20:12>, <DeclarativePart 21425_c.ada:16:18-21:1>, <PackageBody ["B"] 21425_c.ada:16:1-21:7>, <LibraryItem 21425_c.ada:16:1-21:7>, <CompilationUnit 21425_c.ada:16:1-21:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 17:40
# Lookup: <SubpBody ["Bar"] 21425_c.ada:17:4-20:12>
# Parents:  [<SubpBody ["Bar"] 21425_c.ada:17:4-20:12>, <AdaNodeList 21425_c.ada:16:19-20:12>, <DeclarativePart 21425_c.ada:16:18-21:1>, <PackageBody ["B"] 21425_c.ada:16:1-21:7>, <LibraryItem 21425_c.ada:16:1-21:7>, <CompilationUnit 21425_c.ada:16:1-21:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 17:40
# S: 17:38
# E: 17:41
# Location: 18:8
# Lookup: <SubpBody ["Bar"] 21425_c.ada:17:4-20:12>
# Parents:  [<SubpBody ["Bar"] 21425_c.ada:17:4-20:12>, <AdaNodeList 21425_c.ada:16:19-20:12>, <DeclarativePart 21425_c.ada:16:18-21:1>, <PackageBody ["B"] 21425_c.ada:16:1-21:7>, <LibraryItem 21425_c.ada:16:1-21:7>, <CompilationUnit 21425_c.ada:16:1-21:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 18:8
# S: 17:38
# E: 17:41
# Location: 19:17
# Lookup: <Int 21425_c.ada:19:16-19:17>
# Parents:  [<Int 21425_c.ada:19:16-19:17>, <BinOp 21425_c.ada:19:12-19:17>, <AssignStmt 21425_c.ada:19:7-19:18>, <StmtList 21425_c.ada:19:7-19:18>, <HandledStmts 21425_c.ada:18:9-20:4>, <SubpBody ["Bar"] 21425_c.ada:17:4-20:12>, <AdaNodeList 21425_c.ada:16:19-20:12>, <DeclarativePart 21425_c.ada:16:18-21:1>, <PackageBody ["B"] 21425_c.ada:16:1-21:7>, <LibraryItem 21425_c.ada:16:1-21:7>, <CompilationUnit 21425_c.ada:16:1-21:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 20:11
# Lookup: <Id "Bar" 21425_c.ada:20:8-20:11>
# Parents:  [<Id "Bar" 21425_c.ada:20:8-20:11>, <EndName 21425_c.ada:20:8-20:11>, <SubpBody ["Bar"] 21425_c.ada:17:4-20:12>, <AdaNodeList 21425_c.ada:16:19-20:12>, <DeclarativePart 21425_c.ada:16:18-21:1>, <PackageBody ["B"] 21425_c.ada:16:1-21:7>, <LibraryItem 21425_c.ada:16:1-21:7>, <CompilationUnit 21425_c.ada:16:1-21:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Location: 21:6
# Lookup: <Id "B" 21425_c.ada:21:5-21:6>
# Parents:  [<Id "B" 21425_c.ada:21:5-21:6>, <EndName 21425_c.ada:21:5-21:6>, <PackageBody ["B"] 21425_c.ada:16:1-21:7>, <LibraryItem 21425_c.ada:16:1-21:7>, <CompilationUnit 21425_c.ada:16:1-21:7>, <CompilationUnitList 21425_c.ada:1:1-21:7>]
# Unpredictable: {3, 6, 11, 12, 15, 17, 20, 21}
# Found: PragmaNode 1:14-1:37
# ---
# Found: Params 2:18-2:38
# ---
# Found: Identifier 3:5-3:6
# ---
# Found: Identifier 4:6-4:7
# ---
# Found: PragmaNode 5:19-5:42
# ---
# Found: SubpBody 6:4-11:12
# ---
# Found: Identifier 7:11-7:18
# ---
# Found: SubpBody 6:4-11:12
# ---
# Found: CallExpr 9:7-9:16
# ---
# Found: IntLiteral 10:16-10:17
# ---
# Found: Identifier 11:8-11:11
# ---
# Found: Identifier 12:5-12:6
# ---
# Found: PragmaNode 13:14-13:37
# ---
# Found: Params 14:18-14:38
# ---
# Found: Identifier 15:5-15:6
# ---
# Found: PragmaNode 16:19-16:42
# ---
# Found: SubpBody 17:4-20:12
# ---
# Found: SubpBody 17:4-20:12
# ---
# Found: IntLiteral 19:16-19:17
# ---
# Found: Identifier 20:8-20:11
# ---
# Found: Identifier 21:5-21:6
# ---
